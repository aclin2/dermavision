# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-d24e241cd1fb> in <cell line: 13>()
#      11
#      12 # Resize images
# ---> 13 for filename in os.listdir(input_directory):
#      14     if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
#      15         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/DarkerSkin.zip'

# %%
# !unzip /content/sample_data/not_infacted-2.zip
# Out:
# Archive:  /content/sample_data/not_infacted-2.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/sample_data/not_infacted-2.zip or
#         /content/sample_data/not_infacted-2.zip.zip, and cannot find /content/sample_data/not_infacted-2.zip.ZIP, period.

# %%
from PIL import Image
import os

# where images are stored
input_directory = "/content/DarkerSkin_RGB"
output_directory = '/content/new'

# Resize images
for filename in os.listdir(input_directory):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
        try:
            # Open an image file
            with Image.open(os.path.join(input_directory, filename)) as img:
                # Resize image
                img = img.resize((512, 512), Image.ANTIALIAS)
                # Save image
                img.save(os.path.join(output_directory, filename))

print("Resizing complete.")
# Out:
# <ipython-input-6-792fb92e81c6>:19: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((512, 512), Image.ANTIALIAS)
# Resized and saved 33.jpeg
# Resized and saved 80.jpeg
# Resized and saved 77.jpeg
# Resized and saved 85.jpeg
# Resized and saved screenie13.jpeg
# Resized and saved screenie12.jpeg
# Resized and saved 45.jpeg
# Resized and saved screenie4.jpeg
# Resized and saved 67.jpeg
# Resized and saved screenie9.jpeg
# Resized and saved 74.jpeg
# Resized and saved 83.jpeg
# Resized and saved 53.jpeg
# Resized and saved 90.jpeg
# Resized and saved 75.jpeg
# Resized and saved 94.jpeg
# Resized and saved 32.jpeg
# Resized and saved screenie24.jpeg
# Resized and saved 62.jpeg
# Resized and saved 48.jpeg
# Resized and saved 78.jpeg
# Resized and saved 57.jpeg
# Resized and saved 82.jpeg
# Resized and saved 89.jpeg
# Resized and saved screenie18.jpeg
# Resized and saved screenie20.jpeg
# Resized and saved 58.jpeg
# Resized and saved 87.jpeg
# Resized and saved screenie10.jpeg
# Resized and saved 86.jpeg
# Resized and saved 56.jpeg
# Resized and saved 81.jpeg
# Resized and saved screenie21.jpeg
# Resized and saved 37.jpeg
# Resized and saved 93.jpeg
# Resized and saved 88.jpeg
# Resized and saved screenie19.jpeg
# Resized and saved 54.jpeg
# Resized and saved 49.jpeg
# Resized and saved 44.jpeg
# Resized and saved 64.jpeg
# Resized and saved 27.jpeg
# Resized and saved 68.jpeg
# Resized and saved screenie22.jpeg
# Resized and saved 92.jpeg
# Resized and saved 65.jpeg
# Resized and saved 46.jpeg
# Resized and saved 91.jpeg
# Resized and saved 76.jpeg
# Resized and saved screenie14.jpeg
# Resized and saved 95.jpeg
# Resized and saved screenie16.jpeg
# Resized and saved 52.jpeg
# Resized and saved 59.jpeg
# Resized and saved 26.jpeg
# Resized and saved 60.jpeg
# Resized and saved screenie1.jpeg
# Resized and saved screenie7.jpeg
# Resized and saved 41.jpeg
# Resized and saved 40.jpeg
# Resized and saved screenie2.jpeg
# Resized and saved 35.jpeg
# Resized and saved 79.jpeg
# Resized and saved screenie23.jpeg
# Resized and saved 28.jpeg
# Resized and saved 72.jpeg
# Resized and saved 25.jpeg
# Resized and saved 61.jpeg
# Resized and saved 70.jpeg
# Resized and saved 43.jpeg
# Resized and saved 47.jpeg
# Resized and saved 34.jpeg
# Resized and saved 69.jpeg
# Resized and saved screenie8.jpeg
# Resized and saved 55.jpeg
# Resized and saved 71.jpeg
# Resized and saved 31.jpeg
# Resized and saved screenie15.jpeg
# Resized and saved screenie17.jpeg
# Resized and saved 39.jpeg
# Resized and saved 84.jpeg
# Resized and saved screenie5.jpeg
# Resized and saved 38.jpeg
# Resized and saved 66.jpeg
# Resized and saved screenie3.jpeg
# Resized and saved screenie6.jpeg
# Resized and saved 51.jpeg
# Resized and saved 29.jpeg
# Resized and saved 42.jpeg
# Resized and saved screenie11.jpeg
# Resized and saved 36.jpeg
# Resized and saved 96.jpeg
# Resized and saved 30.jpeg
# Resized and saved 73.jpeg
# Resized and saved 50.jpeg
# Resized and saved 63.jpeg
# Resizing complete.
