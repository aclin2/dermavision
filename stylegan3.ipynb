# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     116   """Internal helper to mount Google Drive."""
#     117   if not _os.path.exists('/var/colab/hostname'):
# --> 118     raise NotImplementedError(
# ...

# %%
# !pip install ninja opensimplex
# !git clone https://github.com/NVlabs/stylegan3.git
# !pip install torch torchvision
# !pip install click requests tqdm pyspng imageio-ffmpeg==0.4.3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.0/268.0 kB 32.1 MB/s eta 0:00:00
# ...
# Cloning into 'stylegan3'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 212 (delta 0), reused 1 (delta 0), pack-reused 207 (from 1)
# Receiving objects: 100% (212/212), 4.16 MiB | 19.56 MiB/s, done.
# Resolving deltas: 100% (101/101), done.
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...

# %%
# !unzip hackcmu/DarkerSkin_RGB.zip
# Out:
# Archive:  hackcmu/DarkerSkin_RGB.zip
#    creating: datasets/DarkerSkin_RGB/
#   inflating: datasets/DarkerSkin_RGB/56.jpeg
#   inflating: datasets/DarkerSkin_RGB/26.jpeg
#   inflating: datasets/DarkerSkin_RGB/30.jpeg
#   inflating: datasets/DarkerSkin_RGB/screenie4.jpeg
#   inflating: datasets/DarkerSkin_RGB/70.jpeg
#   inflating: datasets/DarkerSkin_RGB/83.jpeg
#   inflating: datasets/DarkerSkin_RGB/27.jpeg
#   inflating: datasets/DarkerSkin_RGB/34.jpeg
#   inflating: datasets/DarkerSkin_RGB/79.jpeg
#   inflating: datasets/DarkerSkin_RGB/44.jpeg
#   inflating: datasets/DarkerSkin_RGB/screenie23.jpeg
#   inflating: datasets/DarkerSkin_RGB/92.jpeg
#   inflating: datasets/DarkerSkin_RGB/58.jpeg
#   inflating: datasets/DarkerSkin_RGB/59.jpeg
#   inflating: datasets/DarkerSkin_RGB/91.jpeg
#   inflating: datasets/DarkerSkin_RGB/screenie9.jpeg
#   inflating: datasets/DarkerSkin_RGB/73.jpeg
#   inflating: datasets/DarkerSkin_RGB/69.jpeg
#   inflating: datasets/DarkerSkin_RGB/81.jpeg
# ...

# %%
# !python stylegan3/dataset_tool.py --source /content/datasets/DarkerSkin_RGB/ --dest /content/eczema_dataset.zip
# Out:
# 100% 96/96 [00:01<00:00, 65.98it/s]

# %%
# !python stylegan3/train.py \
    --outdir /content/hackcmu/stylegan3-training-runs \
    --cfg stylegan3-r \
    --data /content/eczema_dataset.zip \
    --gpus 1 \
    --batch 8 \
    --gamma 8 \
    --snap 10
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 65536,
#     "channel_max": 1024,
#     "magnitude_ema_beta": 0.9997227795604651,
#     "conv_kernel": 1,
#     "use_radial_filters": true
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
# ...

# %%
# !python stylegan3/gen_images.py \
    --outdir /content/hackcmu/stylegan3_generated_images \
    --network /content/hackcmu/stylegan3-training-runs/stylegan31/network-snapshot-000000.pkl \
    --seeds 1000-1100 \
    --trunc 1.0
# Out:
# Loading networks from "/content/hackcmu/stylegan3-training-runs/stylegan31/network-snapshot-000000.pkl"...
# Generating image for seed 1000 (0/101) ...
# Setting up PyTorch plugin "bias_act_plugin"... /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1967: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1967: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Done.
# Generating image for seed 1001 (1/101) ...
# Generating image for seed 1002 (2/101) ...
# Generating image for seed 1003 (3/101) ...
# Generating image for seed 1004 (4/101) ...
# ...

# %%
# Fine-tune StyleGAN3-R for MetFaces-U using 1 GPU, starting from the pre-trained FFHQ-U pickle.
python train.py --outdir=~/training-runs --cfg=stylegan3-r --data=~/datasets/DarkerSkin_RGB.zip \
    --gpus=8 --batch=32 --gamma=6.6 --mirror=1 --kimg=5000 --snap=5 \
    --resume=https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-r-ffhqu-1024x1024.pkl
# Out:
#   File "<ipython-input-27-5821c8735116>", line 4
#     --resume=https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-r-ffhqu-1024x1024.pkl
#                                                                                                                   ^
# SyntaxError: invalid decimal literal

# %%
# !ls /content/hackcmu/stylegan3_generated_images
# Out:
# seed0000.png  seed0029.png  seed0058.png  seed0087.png	seed1015.png  seed1044.png  seed1073.png
# seed0001.png  seed0030.png  seed0059.png  seed0088.png	seed1016.png  seed1045.png  seed1074.png
# seed0002.png  seed0031.png  seed0060.png  seed0089.png	seed1017.png  seed1046.png  seed1075.png
# seed0003.png  seed0032.png  seed0061.png  seed0090.png	seed1018.png  seed1047.png  seed1076.png
# seed0004.png  seed0033.png  seed0062.png  seed0091.png	seed1019.png  seed1048.png  seed1077.png
# seed0005.png  seed0034.png  seed0063.png  seed0092.png	seed1020.png  seed1049.png  seed1078.png
# seed0006.png  seed0035.png  seed0064.png  seed0093.png	seed1021.png  seed1050.png  seed1079.png
# seed0007.png  seed0036.png  seed0065.png  seed0094.png	seed1022.png  seed1051.png  seed1080.png
# seed0008.png  seed0037.png  seed0066.png  seed0095.png	seed1023.png  seed1052.png  seed1081.png
# seed0009.png  seed0038.png  seed0067.png  seed0096.png	seed1024.png  seed1053.png  seed1082.png
# ...

# %%
# !zip -r /content/hackcmu/stylegan3_generated_images.zip /content/hackcmu/stylegan3_generated_images
# Out:
#   adding: content/hackcmu/stylegan3_generated_images/ (stored 0%)
#   adding: content/hackcmu/stylegan3_generated_images/seed1008.png (deflated 0%)
#   adding: content/hackcmu/stylegan3_generated_images/seed0075.png (deflated 0%)
#   adding: content/hackcmu/stylegan3_generated_images/seed0027.png (deflated 0%)
#   adding: content/hackcmu/stylegan3_generated_images/seed0043.png (deflated 0%)
#   adding: content/hackcmu/stylegan3_generated_images/seed1043.png (deflated 0%)
#   adding: content/hackcmu/stylegan3_generated_images/seed0051.png (deflated 0%)
#   adding: content/hackcmu/stylegan3_generated_images/seed0096.png (deflated 0%)
#   adding: content/hackcmu/stylegan3_generated_images/seed1084.png (deflated 0%)
#   adding: content/hackcmu/stylegan3_generated_images/seed1087.png (deflated 0%)
#   adding: content/hackcmu/stylegan3_generated_images/seed0081.png (deflated 0%)
#   adding: content/hackcmu/stylegan3_generated_images/seed0022.png (deflated 0%)
# ...
